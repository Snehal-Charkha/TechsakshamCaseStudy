# %%
df=pd.read_csv(r"C:\Users\sneha\Downloads\archive (9).zip")
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='object')

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Unit Price")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='object')

# %%
columns_plot=[ 'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
       'Payment Method']
for i in columns_plot:
    bar_plot(i)
# Out:
# Units Sold:
#  Units Sold
# 1     97
# 2     64
# 3     44
# 4     23
# 5      7
# 6      4
# 10     1
# Name: count, dtype: int64
# Unit Price:
#  Unit Price
# 49.99     9
# 299.99    8
# 199.99    7
# 29.99     7
# 399.99    7
#          ..
# 24.00     1
# 32.95     1
# 299.00    1
# 90.00     1
# 55.00     1
# Name: count, Length: 117, dtype: int64
# Total Revenue:
#  Total Revenue
# 299.99    5
# 149.95    4
# 199.99    4
# 399.99    4
# 499.99    4
#          ..
# 98.85     1
# 299.00    1
# 270.00    1
# 55.00     1
# 59.98     1
# Name: count, Length: 173, dtype: int64
# Region:
#  Region
# North America    80
# Europe           80
# Asia             80
# Name: count, dtype: int64
# Payment Method:
#  Payment Method
# Credit Card    120
# PayPal          80
# Debit Card      40
# Name: count, dtype: int64

# %%
plt.hist(df['Product Category'])
plt.show()

# %%
columns_plot=[ 'Date', 'Product Category', 'Product Name',
       'Units Sold', 'Unit Price', 'Total Revenue']
for i in columns_plot:
    bar_plot(i)
# Out:
# Date:
#  Date
# 2024-01-01    1
# 2024-01-02    1
# 2024-01-03    1
# 2024-01-04    1
# 2024-01-05    1
#              ..
# 2024-08-23    1
# 2024-08-24    1
# 2024-08-25    1
# 2024-08-26    1
# 2024-08-27    1
# Name: count, Length: 240, dtype: int64
# Product Category:
#  Product Category
# Electronics        40
# Home Appliances    40
# Clothing           40
# Books              40
# Beauty Products    40
# Sports             40
# Name: count, dtype: int64
# Product Name:
#  Product Name
# Dyson Supersonic Hair Dryer                        2
# Garmin Forerunner 945                              2
# Keurig K-Elite Coffee Maker                        2
# Sony WH-1000XM4 Headphones                         2
# Dune by Frank Herbert                              2
#                                                   ..
# Nespresso Vertuo Next Coffee and Espresso Maker    1
# Nike Air Force 1 Sneakers                          1
# The Handmaid's Tale by Margaret Atwood             1
# ...

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='object')

# %%
df[['Payment Method','Transaction ID']].groupby(['Payment Method'],as_index=False).mean().sort_values(by='Transaction ID',ascending=False)
# Out:
#   Payment Method  Transaction ID
# 0    Credit Card    10120.666667
# 2         PayPal    10120.500000
# 1     Debit Card    10120.000000

# %%
sns.boxplot(x='Product Category',
y ='Units Sold',data=df)
# Out:
# <Axes: xlabel='Product Category', ylabel='Units Sold'>

# %%
sns.boxplot(x='Total Revenue',
y ='Region',data=df)
# Out:
# <Axes: xlabel='Total Revenue', ylabel='Region'>

# %%
df.isna()
# Out:
#      Transaction ID   Date  Product Category  Product Name  Units Sold  \
# 0             False  False             False         False       False
# 1             False  False             False         False       False
# 2             False  False             False         False       False
# 3             False  False             False         False       False
# 4             False  False             False         False       False
# ..              ...    ...               ...           ...         ...
# 235           False  False             False         False       False
# 236           False  False             False         False       False
# 237           False  False             False         False       False
# 238           False  False             False         False       False
# 239           False  False             False         False       False
#
#      Unit Price  Total Revenue  Region  Payment Method
# 0         False          False   False           False
# ...

# %%
sns.boxplot(df['Transaction ID'])
# Out:
# <Axes: ylabel='Transaction ID'>

# %%
df['Total Revenue']=df['Total Revenue'].fillna(df['Total Revenue'].median())

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product Category    0
# Product Name        0
# Units Sold          0
# Unit Price          0
# Total Revenue       0
# Region              0
# Payment Method      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='object')

# %%
df['Date'].mode()
# Out:
# 0      2024-01-01
# 1      2024-01-02
# 2      2024-01-03
# 3      2024-01-04
# 4      2024-01-05
#           ...
# 235    2024-08-23
# 236    2024-08-24
# 237    2024-08-25
# 238    2024-08-26
# 239    2024-08-27
# Name: Date, Length: 240, dtype: object

# %%
df['Date']=df['Date'].fillna(df['Date'].mode()[0])

# %%
df.head(3)
# Out:
#    Transaction ID        Date Product Category      Product Name  Units Sold  \
# 0           10001  2024-01-01      Electronics     iPhone 14 Pro           2
# 1           10002  2024-01-02  Home Appliances  Dyson V11 Vacuum           1
# 2           10003  2024-01-03         Clothing  Levi's 501 Jeans           3
#
#    Unit Price  Total Revenue         Region Payment Method
# 0      999.99        1999.98  North America    Credit Card
# 1      499.99         499.99         Europe         PayPal
# 2       69.99         209.97           Asia     Debit Card

# %%
df.info
# Out:
# <bound method DataFrame.info of      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...
